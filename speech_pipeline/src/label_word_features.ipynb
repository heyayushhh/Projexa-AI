# %%
import pandas as pd

df = pd.read_csv("../output/word_level_features_test.csv")

print(df.head())
print("Total rows:", len(df))
# Out:
#           word  start    end  duration  rms_mean  zcr_mean  mfcc_0_mean  \
# 0           Hi  16.04  16.92  0.880000  0.035657  0.048235   -285.56296
# 1   everybody,  16.92  17.80  0.880062  0.054236  0.162789   -194.70546
# 2         this  18.10  18.26  0.160000  0.033701  0.293376   -212.18591
# 3           is  18.26  18.42  0.160000  0.021272  0.378662   -244.27864
# 4          Pam  18.42  18.70  0.280000  0.040905  0.320475   -230.54237
#
#    mfcc_1_mean  mfcc_2_mean  mfcc_3_mean  mfcc_4_mean  mfcc_5_mean  \
# 0   154.945660   -29.796968    46.030666    -5.501808    16.915274
# 1    44.036280   -35.103725    42.972706   -28.866024    15.077125
# 2   -26.978249   -13.203340    24.342972   -20.205593   -22.637121
# 3   -56.220066    34.711277    25.230003    12.237439     1.784218
# 4   -19.837448   -17.651588    50.262783   -44.827210    -2.093471
#
#    mfcc_6_mean  mfcc_7_mean  mfcc_8_mean  mfcc_9_mean  mfcc_10_mean  \
# ...

# %%
df["label"] = -1   # -1 = unlabeled

# %%
LABELED_PATH = "../output/word_level_features_labeled.csv"
df.to_csv(LABELED_PATH, index=False)

print("Saved file for labeling:", LABELED_PATH)
# Out:
# Saved file for labeling: ../output/word_level_features_labeled.csv

# %%
import pandas as pd
import os
import requests
import subprocess
from faster_whisper import WhisperModel

# %%
# --------------------------------------------------
# STEP 1: Read CSV and get audio URL
# --------------------------------------------------

cols = ["Podcast_Name", "Episode_Name", "Audio_URL", "Source", "Index"]
df = pd.read_csv("../audio_links.csv", header=None, names=cols)

print("CSV Loaded:")
print(df.head())

urls = df["Audio_URL"].tolist()
print("\nFirst 3 URLs:")
print(urls[:3])
# Out:
# CSV Loaded:
#                                         Podcast_Name  \
# 0  He_Stutters_Podcast_–_Make_Room_For_The_Stutte...
# 1  He_Stutters_Podcast_–_Make_Room_For_The_Stutte...
# 2  He_Stutters_Podcast_–_Make_Room_For_The_Stutte...
# 3  He_Stutters_Podcast_–_Make_Room_For_The_Stutte...
# 4  He_Stutters_Podcast_–_Make_Room_For_The_Stutte...
#
#                  Episode_Name  \
# 0   episode-208-with-kelsey-h
# 1   episode-208-with-kelsey-h
# 2   episode-208-with-kelsey-h
# 3   episode-208-with-kelsey-h
# 4   episode-208-with-kelsey-h
#
#                                            Audio_URL       Source  Index
# 0   https://stutterrockstar.files.wordpress.com/2...   HeStutters      0
# 1   https://stutterrockstar.files.wordpress.com/2...   HeStutters      1
# 2   https://stutterrockstar.files.wordpress.com/2...   HeStutters      2
# 3   https://stutterrockstar.files.wordpress.com/2...   HeStutters      3
# 4   https://stutterrockstar.files.wordpress.com/2...   HeStutters      4
#
# First 3 URLs:
# [' https://stutterrockstar.files.wordpress.com/2011/05/male-episode-1-with-alan1.mp3', ' https://stutterrockstar.files.wordpress.com/2012/04/male-episode-10-with-landon.mp3', ' https://stutterrockstar.files.wordpress.com/2012/05/male-episode-11-with-frank.mp3']

# %%
# --------------------------------------------------
# STEP 2: Download MP3
# --------------------------------------------------

os.makedirs("../audio/downloaded", exist_ok=True)

url = urls[0]
mp3_path = "../audio/downloaded/test.mp3"

response = requests.get(url)

with open(mp3_path, "wb") as f:
    f.write(response.content)

print("\nDownloaded test.mp3")
# Out:
# Downloaded test.mp3

# %%
# --------------------------------------------------
# STEP 3: Convert MP3 → WAV (16kHz, mono)
# --------------------------------------------------

wav_path = "../audio/downloaded/test.wav"

subprocess.run(
    [
        "ffmpeg", "-y",
        "-i", mp3_path,
        "-ac", "1",
        "-ar", "16000",
        wav_path
    ],
    check=True
)

print("Converted to WAV successfully")
# Out:
# Converted to WAV successfully

# %%
# --------------------------------------------------
# STEP 4: Load Whisper model
# --------------------------------------------------

MODEL_PATH = r"C:\whisper_models\faster-whisper-small"

model = WhisperModel(
    MODEL_PATH,
    device="cpu",
    compute_type="int8",
    cpu_threads=4,
    num_workers=1
)

# %%
# --------------------------------------------------
# STEP 5: Transcribe with word timestamps
# --------------------------------------------------

segments, info = model.transcribe(
    wav_path,
    word_timestamps=True
)

# IMPORTANT: convert generator to list
segments = list(segments)

print("\nDetected Language:", info.language)

# Segment-level debug
print("\nSEGMENTS:")
for segment in segments:
    print(segment.start, segment.end, segment.text)
# Out:
# Detected Language: en
#
# SEGMENTS:
# 16.039999999999996 25.98  Hi everybody, this is Pam coming to you from the debut episode of a new addition to the
# 25.98 34.8  blog make room for this uttering. Today I'm going to introduce his stories. She
# 34.8 45.9  asks him and my goal is to introduce a little bit of the male perspective on
# 45.9 54.32  this crazy thing that we all know as stuttering. So for my debut male guest
# 54.32 64.32  I'm really excited to say hello to Alan. Hi Alan, how are you? Good afternoon. It's
# 64.32 72.0  good afternoon here in Wales in the United Kingdom. I suspect it's still morning
# 72.0 84.3  with you or just into the afternoon in the New York area. That is correct. It's
# 84.3 91.38  time and it's a beautiful Saturday afternoon here kind of chilly but it's
# 91.38 96.68  one of those days where I don't mind at all staying in talking with good
# 96.68 105.38  friends and probably later on getting some housework done. Good for you. So Alan,
# 105.7 112.4  for our listeners could you formally introduce yourself, your name and again
# 112.4 119.14  where you're from and what you do with yourself these days? I will introduce
# 119.14 129.44  myself even though as you know I'm a shy and retiring guy. My name is Alan
# 129.44 140.94  Badminton and I'll spell that because everybody spells it incorrectly. B-A-D-M-I-N-G-T-O-N.
# 140.94 149.98  Everybody leaves out the G and I'm from Wales in the United Kingdom and Wales just
# 149.98 157.46  to give you a brief geographical lesson, Wales is one of the four countries that
# 157.46 165.28  make up the United Kingdom along with England, Scotland and Northern Ireland.
# 165.28 172.14  So I live in Wales. I've always lived in Wales and I've lived here for quite a
# 172.14 184.5  long time because I'm getting quite long in the tooth. Okay. I've started, I'm so
# 184.5 191.64  sorry I interrupted you, I was just going to say I've started since the very
# 191.64 207.06  early age of three. And you speak obviously very clearly and very fluidly as we're
# 207.06 214.74  hearing you. You've stuttered since the age of three so what type of strategies
# 215.34 222.94  techniques have you employed over the years to attain the eloquence that I'm
# 222.94 231.88  hearing from you now? You don't have long enough in this podcast for me to outline
# 231.88 240.5  all the different things that I've tried. I had speech therapy when I was very
# 240.5 249.58  young that didn't work. I got by in school and it was only really when I went to
# 249.58 257.58  the grammar school at the age of 11 and I have vivid memories of struggling to
# 257.58 263.98  give my name and address at the initial registration and reading a
# 263.98 271.7  shouting class was a nightmare. And as the reading would be going around the room I
# 271.7 281.06  would be scanning ahead, 10 desks ahead to check the words that I thought I was
# 281.06 286.52  going to have to say. And I would realize that there were many, many in
# 286.52 292.74  the passages that I could not say and I would opt out. So that's my school I
# 292.74 299.34  never asked nor responded to questions in class for fear of looking a fool. I knew
# 299.34 307.0  the answers I wanted to participate but I kept my mouth shut. It was so
# 307.0 314.7  frustrating. Moving on through adolescence I didn't have any further
# 314.7 325.08  speech therapy. And then at the age of 19 when my hair was dark and I didn't have
# 325.08 334.62  a wrinkle in sight I did something that most people would consider idiotic for
# 334.62 341.94  someone with a stutter, a severe stutter because it was that severe that I
# 341.94 349.66  couldn't say 13 letters of the alphabet. And worse of all of course I couldn't say
# 349.66 355.52  letters B which was a problem because my name was and believe it or not it still
# 355.52 370.2  is badminton. But there was BC D F G K L M N P S T and V I never ever ever used
# 370.2 376.56  and I became an expert at providing synonyms words meaning the same but
# 376.56 384.86  commencing with a different letter. I became a walking thesaurus. But when I
# 384.86 391.68  joined the police service the only way in which I was able to gain acceptance
# 391.68 402.14  was during the interview. I very carefully selected the words that I knew I
# 402.14 408.32  could say and I answered and I didn't display a great deal of stuttering
# 408.32 415.92  because I was using avoidance techniques and I was accepted. What made
# 417.15999999999997 424.54  you want to get into police service knowing that you likely would have
# 424.54 434.92  difficulty with communicating? From a very early age Pam I realized that there
# 434.92 443.0  were many ways that I could live my life. I knew that I could take a
# 443.0 451.28  relatively easy passage by avoiding social interaction, by avoiding employment
# 451.28 459.0  that didn't require a great deal of speaking because as you and I and many
# 459.0 465.74  others who will listen to this podcast will know it is so easy to overcome
# 465.74 477.22  stuttering. Yes it is by not speaking but what good is that and so I decided that
# 477.22 484.62  I needed to challenge myself. I needed to place myself in a position where I had
# 484.62 492.08  contact with the public and that is why I decided to join the police at
# 492.08 503.18  the age of 19. Were you successful? I was accepted and of course in the
# 503.18 510.26  beginning you have to go out on to foot patrol, street duties, operational work
# 510.26 518.18  and I relied so heavily on word substitution if someone wanted to know
# 518.18 525.06  the time I'd show them my watch. If they wanted directions I'd draw them on a
# 525.06 533.1  piece of paper and I would use word substitution at all times but as you know
# 533.88 542.3800000000001  every time you avoid a word, a letter or a situation the fair level grows and
# 542.38 553.08  grows and grows and I hid for so long but the time finally came when I had to
# 553.08 559.04  say a particular word I had to speak in a particular situation and the crunch
# 559.04 566.54  oh my gosh I can remember it so clearly. The crunch came for me Pam when I had
# 566.54 573.24  to give evidence in court for the very first time and I can remember it as
# 573.24 579.38  clearly as though it were yesterday. It's making me sweat now I'm beginning to
# 579.38 586.88  perspire recounting that experience and I walked into the courtroom as a
# 586.88 595.58  fresh-faced 19 year old with every eye upon me and I stepped up into the
# 595.58 603.72  wooden witness box I place my left hand on the Bible I raise my right hand in the
# 603.72 613.5  air and I said I sa sa I I I I I sa and that's as far as I got because the
# 613.5 622.3000000000001  oath comprised 23 words and I knew well in advance that there were 19 I
# 622.34 630.1  couldn't say and so I was filled with fair intrepidation in the weeks leading up
# 630.1 637.08  to that court appearance and I started so badly that the only way in which I
# 637.08 642.88  could say the oath was for the clock of the court to repeat the oath to say the
# 642.88 648.34  oath first of all and then ask me and I would say I do that's all I had to
# 648.34 659.26  say was I do it was a struggle but there's worse to come when you give evidence
# 659.26 668.28  in court you don't just give the oath then came the evidence in chief and you
# 668.28 675.72  can't and I relied so heavily on word substitution but you can't change the
# 675.72 682.92  defendant's name you can't change the date the time the place of the offense you
# 682.92 689.0  can't change the registration number the registration mark the make of the motor
# 689.0 698.08  vehicle they're all non-negotiable when I found a drunk lying in Somerset
# 698.08 704.68  street for example it was a huge temptation Pam to dragging him or drag
# 704.68 710.76  him around into the adjoining street before I made the arrest into a street
# 710.76 720.18  which didn't start with one of my feared letters and I'm sure it won't go any
# 720.18 727.68  further than this conversation but I did that on many many occasions it was the
# 727.68 737.1200000000001  only way in which I could exist and the problems I had in court was so bad that a
# 737.8 742.7  senior officer wrote of me and I've still got this report to this very day he
# 742.7 751.16  said when this officer gives evidence in court he is an embarrassment to all
# 751.16 757.6  and I've still got that report all these years later but even worse than that
# 757.6 764.02  a couple of years later he also wrote the only reason that this officer is not
# 764.02 771.76  being considered for promotion is his speech impediment and when I was a very
# 1847.46 1859.46  or one situation and that has been a tremendous asset in helping me to come
# 1859.46 1867.8  to terms with my stuttering issues so what was it actually I mean what was it
# 1867.8 1875.92  that worked was it just the change of my mindset was it just purely facing
# 1875.92 1887.84  your greatest fears on that course they drilled certain techniques I learned a new
# 1887.84 1893.64  method of breathing which virtually helped me to overcome the speech block
# 1893.64 1900.64  overnight I then learned ways of dealing with those 13 letters which
# 1900.76 1908.32  always given me so many problems and so that course wasn't the be all and end all
# 1908.32 1916.02  it wasn't the final destination it was the springboard the springboard because
# 1916.02 1925.5  I now knew that I could have control of my speech and so I went away from that
# 1925.5 1934.32  course and what I did I devised my own plan of action I drew up a plan of action
# 1934.32 1941.5  where I challenged myself I expanded my comfort zones every day from the moment
# 1941.5 1949.34  I got up in the morning until the moment I went to bed at night I joined as public
# 1949.34 1955.94  speaking club no I tell a lie I joined three public speaking clubs three I would
# 1955.94 1962.38  travel a hundred miles to a public speaking club just to practice my new
# 1962.38 1971.14  techniques my new control I would pluck three phone numbers from yellow yellow
# 1971.14 1976.82  pages I would call them for two to three hours a day making fictitious
# 1976.82 1983.54  inquiries all I wanted to do was to talk talk talk and I was doing it at somebody
# 1983.54 1996.62  else's expense you're a smart man Alan but no I identified myself limiting
# 1996.62 2006.0  beliefs and I challenged those beliefs on a daily basis because what we
# 2006.0 2013.94  believe and how we see ourselves influences our thoughts and what we think
# 2013.94 2021.4  shapes our behaviors so if you identify yourself limiting beliefs if you challenge
# 2021.4 2030.64  them or I challenge them I became I acquired more empowering beliefs my
# 2030.64 2039.36  thought became more empowering my self-image our self-image sets the
# 2039.36 2044.64  boundaries to our accomplishment it creates us the it creates the scripts
# 2044.64 2054.18  by which we act out our lives so it all depends on how you see yourself if you
# 2054.18 2061.8  can change your self-image make it more empowering enlarge it embrace these new
# 2061.8 2068.64  roles and the more I did these new roles I became more comfortable in doing them
# 2068.64 2076.94  and now I fully accept many many roles that for so many years lay outside my
# 2076.94 2085.76  scope because I thought I couldn't do them it almost seems to me that you're a
# 2085.76 2093.96  completely different per person than you once were is that a fair presumption I'm
# 2093.96 2105.02  always been a happy jokey outgoing individual even though I started but I
# 2106.0600000000004 2115.3  was wearing shackles I was wearing shackles some people now say I talk too
# 2115.3 2121.02  much Pam to a charge a charge to which I willingly plead guilty but I have
# 2121.02 2128.42  waited for more than 50 years to be able to say exactly what I want to say the
# 2128.42 2137.14  debilitating oral shackles that inhibited me since childhood have finally been
# 2137.14 2144.34  removed and I can pluck whatever words I choose from the extremities of my
# 2144.34 2150.22  vocabulary and say them without the fear of stuttering there's no fear I still
# 2150.22 2158.38  get the occasional very occasional reminder but they are few and far between
# 2158.38 2165.58  and yes I am a much more assertive individual you have to become I believe
# 2165.58 2175.14  more assertive but the danger if that is the word that when we become more
# 2175.14 2184.44  assertive when we change the people with whom we live our partners our wives our
# 2184.44 2194.84  husband now see are now living with a different human being it's they are not
# 2194.84 2206.54  the people that they possibly fell in love with and the roles which we have or the
# 2206.54 2213.92  roles which I had when I studied they changed there were many instances where
# 2214.44 2223.78  my my wife would help out make telephone calls on my behalf order for
# 2223.78 2230.98  me at a restaurant the moment I came home from that course on the fourth of May
# 2230.98 2239.98  2000 I explained to her thank you for everything that you have done thank you
# 2239.98 2244.98  for all the support that you've given me over the years but please from now
# 2244.98 2253.96  on I must accept responsibility for every speaking situation that I have to
# 2253.96 2264.74  perform if I hadn't explained she may have felt a little redundant she was so
# 2264.74 2272.72  so understanding we have a wonderful wonderful relationship but I have seen
# 2272.72 2282.96  people change and have problems with their relationships because change changes
# 2282.96 2293.46  everything you're not the person the roles which you have fulfilled the
# 2293.46 2303.3  boundaries the guidelines they change mm-hmm and so you need to consult you
# 2303.3 2311.3  need to share you need to speak otherwise I know from other people that it
# 2311.3 2316.74  has caused them problems thankfully it hasn't caused any problems in our
# 2316.74 2323.2  household whatsoever because my wife has been so so supportive and I just like
# 2323.2 2332.88  to say she didn't twist my arm to go on that course because she didn't love me
# 2332.88 2344.02  as I was she did that because she knew that I had had to accept second best for
# 2344.02 2351.7  so much of my life and she knew that I would be happier fulfilling my true
# 2351.7 2365.9  potential and that is why she poked me to attend that course in 2000 sounds like it
# 2365.9 2371.48  was the very best thing that you that that that the very best gift that she
# 2371.48 2382.5  gave you yes but I had to move on from that course although that course provided
# 2382.5 2393.2  wonderful support I took that support for a while but I knew that if I if I
# 2393.2 2400.18  really wanted to deal wholly with my stuttering issues not just in a course
# 2400.18 2408.3  environment not just at a support group I knew that I had to take responsibility for
# 2408.3 2414.26  the rest of my life and so I have moved away from that course in recent years
# 2414.26 2423.2  but the support which it provided is wonderful but I chose to move on let
# 2423.2 2432.44  me ask you this just to stray a little bit away with your with your very fluent
# 2432.44 2442.54  communication these days what's it like for for you when you interact or speak
# 2442.54 2450.22  with other people who stutter who have not achieved that level of confidence
# 2450.22 2457.2  and fluency does it make you uncomfortable to listen to other people that are
# 2457.2 2464.6  still stuttering does it make you want to suggest to them that they try some
# 2464.6 2472.24  some some some of the techniques that have worked for you no I recognize
# 2472.96 2484.28  that we are all different human beings we commence from different starting lines we
# 2484.28 2493.76  have different life experiences we have different amounts of emotional baggage we
# 2493.76 2505.16  have different aspirations and hopes in life I would never ever ever ever attempt
# 2505.16 2516.32  to coerce anyone to follow in my footpath it worked for me it worked for me I
# 2516.58 2526.56  would never ever dream of telling anyone hey you should do this no no no I will
# 2526.56 2536.36  willingly share my experiences as I am here I still belong to the international
# 2536.36 2543.98  telephone support network which is provided by that stuttering management
# 2543.98 2551.1  program although I no longer attend their courses I no longer attend their support
# 2551.1 2558.42  groups I still support people who are coming through via that international
# 2558.42 2569.1  support network and I speak every day to 10 12 15 I have spoken to as many as
# 2569.1 2578.88  30 different people on one day it's all done completely free of charge without I do
# 2578.88 2589.42  it because I received that help when I needed it no I speak to people who
# 2589.48 2599.92  still stutter very severely every day it doesn't register with me whatsoever I was
# 2599.92 2615.04  in that position myself not so long ago why should I look down on them I it's
# 2615.04 2625.82  just how they speak and I wasn't so suggesting that you would look down on
# 2625.82 2633.06  and on and anybody else who has not achieved the fluency that you have
# 2633.06 2638.14  certainly that's not what I was suggesting I was just you know trying
# 3043.94 3055.4  own experiences is not in any way egotistical I truly believe that when we
# 3056.4 3065.94  bring these positive experiences back into our minds it strengthens our memories
# 3065.94 3073.82  of those experiences and for so long for so long I had so many negative
# 3073.82 3080.64  experiences and I replayed those negative outlooks over and over so now
# 3080.64 3091.82  I reversed it the worm has turned I now remind myself of the things that I have
# 3091.82 3103.36  achieved in life and if along the way someone takes just one little point or
# 3103.36 3111.38  two little points from that journey then it would make it for me all worthwhile
# 3114.06 3124.6  thank you for sharing that and to wrap up this great con con con con conversation
# 3124.6 3134.5  please do share your poem with us it's a poem entitled changing the words around
# 3134.5 3144.92  and you've guessed it's by Alan badminton I couldn't say muffin I couldn't say
# 3144.92 3155.06  butter if I ordered a burger I'd stumble and star star stutter so instead of me
# 3155.06 3163.98  saying the words that I should I'd swap them for others I hoped that I could but
# 3163.98 3169.64  you can't always leave out the words that you dread there are times when a
# 3169.94 3178.06  certain thing has to be said my sisters called Sarah my best friend is Ben they
# 3178.06 3186.78  just wouldn't answer to Lucy and Len whenever I spotted a difficult sound I'd
# 3186.78 3195.12  hastily juggle my sentence around I spent so much energy word rearranging
# 3195.12 3203.32  whenever I spoke I was chopping and changing my efforts to search for an
# 3203.32 3210.82  easier word resulted in sentences sometimes absurd at times my selections
# 3210.82 3219.52  just didn't make sense which made me more anxious frustrated and tense each
# 3219.52 3226.44  time I avoided a troublesome sound I felt rather guilty and very soon found
# 3226.44 3233.08  that my fear of speaking increased even more the number of problem words
# 3233.08 3241.56  started to soar in time I discovered that word substitution was simply
# 3241.56 3251.58  avoidance and not a solution although I was fluent or so it appeared the words I
# 3251.58 3261.7  avoided became much more feared one day I decided enough was enough I made myself
# 3261.7 3269.76  promise although it was tough to say what I wanted whatever the letter at
# 3269.76 3282.2  times I still struggled but I felt so much better today I will say any letter or
# 3282.2 3291.42  sound confronting my fears is the best way I found should I ever be tempted to
# 3291.42 3302.16  waver some time I'll remember the message contained in this rhyme and that's it
# 3302.16 3311.36  Pam oh that was beautiful and that was a per perfect way to end this wonderful
# 3311.36 3317.96  con con con conversation that we've had I want to thank you for sharing and
# 3317.96 3327.14  being a guest on this inaugural episode again thank you for your honesty and
# 3327.14 3335.18  your willingness to share your story thank you for allowing me to go boldly
# 3335.18 3345.08  where no man has previously gone perfect and this has been his stories she
# 3345.08 3346.0  asks him

# %%
# --------------------------------------------------
# STEP 6: Extract word-level timestamps
# --------------------------------------------------

words = []

for segment in segments:
    if segment.words is None:
        continue

    for w in segment.words:
        words.append({
            "word": w.word,
            "start": w.start,
            "end": w.end
        })

print("\nFIRST 10 WORDS WITH TIMESTAMPS:")
print(words[:10])
# Out:
# FIRST 10 WORDS WITH TIMESTAMPS:
# [{'word': ' Hi', 'start': np.float64(16.039999999999996), 'end': np.float64(16.919999999999998)}, {'word': ' everybody,', 'start': np.float64(16.919999999999998), 'end': np.float64(17.8)}, {'word': ' this', 'start': np.float64(18.1), 'end': np.float64(18.26)}, {'word': ' is', 'start': np.float64(18.26), 'end': np.float64(18.42)}, {'word': ' Pam', 'start': np.float64(18.42), 'end': np.float64(18.7)}, {'word': ' coming', 'start': np.float64(18.7), 'end': np.float64(19.56)}, {'word': ' to', 'start': np.float64(19.56), 'end': np.float64(19.9)}, {'word': ' you', 'start': np.float64(19.9), 'end': np.float64(20.16)}, {'word': ' from', 'start': np.float64(20.16), 'end': np.float64(20.5)}, {'word': ' the', 'start': np.float64(20.5), 'end': np.float64(20.74)}]

# %%
# --------------------------------------------------
# STEP 7: Generate RAW transcript
# --------------------------------------------------

raw_text = " ".join(w["word"] for w in words)

print("\nRAW TRANSCRIPT:")
print(raw_text)
# Out:
# RAW TRANSCRIPT:
#  Hi  everybody,  this  is  Pam  coming  to  you  from  the  debut  episode  of  a  new  addition  to  the  blog  make  room  for  this  uttering.  Today  I'm  going  to  introduce  his  stories.  She  asks  him  and  my  goal  is  to  introduce  a  little  bit  of  the  male  perspective  on  this  crazy  thing  that  we  all  know  as  stuttering.  So  for  my  debut  male  guest  I'm  really  excited  to  say  hello  to  Alan.  Hi  Alan,  how  are  you?  Good  afternoon.  It's  good  afternoon  here  in  Wales  in  the  United  Kingdom.  I  suspect  it's  still  morning  with  you  or  just  into  the  afternoon  in  the  New  York  area.  That  is  correct.  It's  time  and  it's  a  beautiful  Saturday  afternoon  here  kind  of  chilly  but  it's  one  of  those  days  where  I  don't  mind  at  all  staying  in  talking  with  good  friends  and  probably  later  on  getting  some  housework  done.  Good  for  you.  So  Alan,  for  our  listeners  could  you  formally  introduce  yourself,  your  name  and  again  where  you're  from  and  what  you  do  with  yourself  these  days?  I  will  introduce  myself  even  though  as  you  know  I'm  a  shy  and  retiring  guy.  My  name  is  Alan  Badminton  and  I'll  spell  that  because  everybody  spells  it  incorrectly.  B -A -D -M -I -N -G -T -O -N.  Everybody  leaves  out  the  G  and  I'm  from  Wales  in  the  United  Kingdom  and  Wales  just  to  give  you  a  brief  geographical  lesson,  Wales  is  one  of  the  four  countries  that  make  up  the  United  Kingdom  along  with  England,  Scotland  and  Northern  Ireland.  So  I  live  in  Wales.  I've  always  lived  in  Wales  and  I've  lived  here  for  quite  a  long  time  because  I'm  getting  quite  long  in  the  tooth.  Okay.  I've  started,  I'm  so  sorry  I  interrupted  you,  I  was  just  going  to  say  I've  started  since  the  very  early  age  of  three.  And  you  speak  obviously  very  clearly  and  very  fluidly  as  we're  hearing  you.  You've  stuttered  since  the  age  of  three  so  what  type  of  strategies  techniques  have  you  employed  over  the  years  to  attain  the  eloquence  that  I'm  hearing  from  you  now?  You  don't  have  long  enough  in  this  podcast  for  me  to  outline  all  the  different  things  that  I've  tried.  I  had  speech  therapy  when  I  was  very  young  that  didn't  work.  I  got  by  in  school  and  it  was  only  really  when  I  went  to  the  grammar  school  at  the  age  of  11  and  I  have  vivid  memories  of  struggling  to  give  my  name  and  address  at  the  initial  registration  and  reading  a  shouting  class  was  a  nightmare.  And  as  the  reading  would  be  going  around  the  room  I  would  be  scanning  ahead,  10  desks  ahead  to  check  the  words  that  I  thought  I  was  going  to  have  to  say.  And  I  would  realize  that  there  were  many,  many  in  the  passages  that  I  could  not  say  and  I  would  opt  out.  So  that's  my  school  I  never  asked  nor  responded  to  questions  in  class  for  fear  of  looking  a  fool.  I  knew  the  answers  I  wanted  to  participate  but  I  kept  my  mouth  shut.  It  was  so  frustrating.  Moving  on  through  adolescence  I  didn't  have  any  further  speech  therapy.  And  then  at  the  age  of  19  when  my  hair  was  dark  and  I  didn't  have  a  wrinkle  in  sight  I  did  something  that  most  people  would  consider  idiotic  for  someone  with  a  stutter,  a  severe  stutter  because  it  was  that  severe  that  I  couldn't  say  13  letters  of  the  alphabet.  And  worse  of  all  of  course  I  couldn't  say  letters  B  which  was  a  problem  because  my  name  was  and  believe  it  or  not  it  still  is  badminton.  But  there  was  BC  D  F  G  K  L  M  N  P  S  T  and  V  I  never  ever  ever  used  and  I  became  an  expert  at  providing  synonyms  words  meaning  the  same  but  commencing  with  a  different  letter.  I  ...

# %%
import pandas as pd
import os
import requests
import subprocess
from faster_whisper import WhisperModel
from tqdm import tqdm

# %%
# --------------------------------------------------
# CONFIG
# --------------------------------------------------

CSV_PATH = "../audio_links.csv"
DOWNLOAD_DIR = "../audio/downloaded"
OUTPUT_CSV = "../output/raw_transcripts.csv"

MODEL_PATH = r"C:\whisper_models\faster-whisper-small"

os.makedirs(DOWNLOAD_DIR, exist_ok=True)
os.makedirs("../output", exist_ok=True)

# %%
# --------------------------------------------------
# LOAD CSV
# --------------------------------------------------

cols = ["Podcast_Name", "Episode_Name", "Audio_URL", "Source", "Index"]
df = pd.read_csv(CSV_PATH, header=None, names=cols)

# %%
# --------------------------------------------------
# LOAD WHISPER MODEL (ONCE)
# --------------------------------------------------

model = WhisperModel(
    MODEL_PATH,
    device="cpu",
    compute_type="int8"
)

results = []

# %%
# --------------------------------------------------
# PROCESS EACH AUDIO FILE
# --------------------------------------------------

for idx, row in tqdm(df.iterrows(), total=len(df)):
    try:
        audio_url = row["Audio_URL"]
        index_id = row["Index"]

        mp3_path = f"{DOWNLOAD_DIR}/{index_id}.mp3"
        wav_path = f"{DOWNLOAD_DIR}/{index_id}.wav"

        # -------- Download audio --------
        if not os.path.exists(mp3_path):
            r = requests.get(audio_url, timeout=30)
            with open(mp3_path, "wb") as f:
                f.write(r.content)
                   # -------- Convert to WAV --------
        subprocess.run(
            [
                "ffmpeg", "-y",
                "-i", mp3_path,
                "-ac", "1",
                "-ar", "16000",
                wav_path
            ],
            stdout=subprocess.DEVNULL,
            stderr=subprocess.DEVNULL,
            check=True
        )

        # -------- Transcribe --------
        segments, info = model.transcribe(wav_path)
        segments = list(segments)

        raw_text = " ".join(segment.text.strip() for segment in segments)

        # -------- Save result --------
        results.append({
            "Podcast_Name": row["Podcast_Name"],
            "Episode_Name": row["Episode_Name"],
            "Audio_URL": audio_url,
            "Index": index_id,
            "Language": info.language,
            "Raw_Transcript": raw_text
        })

    except Exception as e:
        print(f"❌ Failed for index {row['Index']}: {e}")
        continue

# %%
     
# --------------------------------------------------
# SAVE OUTPUT
# --------------------------------------------------

output_df = pd.DataFrame(results)
output_df.to_csv(OUTPUT_CSV, index=False)

print(f"\n✅ Saved raw transcripts to {OUTPUT_CSV}")

# %%
import pandas as pd

# %%
df = pd.read_csv("train_dataset.csv")

# %%
df.shape
# Out:
# (26067, 7)

# %%
df["stutter"].value_counts()
# Out:
# stutter
# 1    20866
# 0     5201
# Name: count, dtype: int64
